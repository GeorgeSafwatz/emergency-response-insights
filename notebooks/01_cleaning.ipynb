# %%
import pandas as pd
import sys
import os

sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from src.data_cleaning import parse_timestamps, normalize_zip_codes

df = pd.read_csv(
    "../data/911.csv",
    low_memory=False
)

df = parse_timestamps(df)
df = normalize_zip_codes(df)

df.to_parquet("../data/cleaned_911.parquet", index=False)
